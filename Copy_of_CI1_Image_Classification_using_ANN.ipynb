# %% [markdown]
# <a href="https://colab.research.google.com/github/HariSingh6265/Basics-of-Python/blob/main/Copy_of_CI1_Image_Classification_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial : Covid 19 Prediction using Artificial Neural Networks

# %% [markdown]
# Dataset: [Covid 19 Chest X-ray dataset](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
#
#
# A team of researchers from Qatar University, Doha, Qatar, and the University of Dhaka, Bangladesh along with their collaborators from Pakistan and Malaysia in collaboration with medical doctors have created a database of chest X-ray images for COVID-19 positive cases along with Normal and Viral Pneumonia images. This COVID-19, normal, and other lung infection dataset is released in stages. In the first release, we have released 219 COVID-19, 1341 normal, and 1345 viral pneumonia chest X-ray (CXR) images. In the first update, we have increased the COVID-19 class to 1200 CXR images. In the 2nd update, we have increased the database to 3616 COVID-19 positive cases along with 10,192 Normal, 6012 Lung Opacity (Non-COVID lung infection), and 1345 Viral Pneumonia images. We will continue to update this database as soon as we have new x-ray images for COVID-19 pneumonia patients.

# %% [markdown]
# **1. Mount the Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **2. Move to the place where data resides**

# %%
# %cd /content/drive/MyDrive/CSIT12025/
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/CSIT12025/'
# /content

# %%
# !ls
# Out:
# covid_dataset.zip  drive  sample_data

# %% [markdown]
# **3. Unziping the dataset**

# %%
# !pip install unzip
# Out:
# Requirement already satisfied: unzip in /usr/local/lib/python3.12/dist-packages (1.0.0)

# %%
# !unzip covid_dataset.zip
# Out:
# Archive:  covid_dataset.zip
#    creating: covid_dataset/
#    creating: covid_dataset/COVID/
#   inflating: covid_dataset/COVID/COVID-1.png
#   inflating: covid_dataset/COVID/COVID-10.png
#   inflating: covid_dataset/COVID/COVID-11.png
#   inflating: covid_dataset/COVID/COVID-12.png
#   inflating: covid_dataset/COVID/COVID-13.png
#   inflating: covid_dataset/COVID/COVID-14.png
#   inflating: covid_dataset/COVID/COVID-15.png
#   inflating: covid_dataset/COVID/COVID-16.png
#   inflating: covid_dataset/COVID/COVID-17.png
#   inflating: covid_dataset/COVID/COVID-18.png
#   inflating: covid_dataset/COVID/COVID-19.png
#   inflating: covid_dataset/COVID/COVID-2.png
#   inflating: covid_dataset/COVID/COVID-20.png
#   inflating: covid_dataset/COVID/COVID-21.png
#   inflating: covid_dataset/COVID/COVID-22.png
#   inflating: covid_dataset/COVID/COVID-23.png
#   inflating: covid_dataset/COVID/COVID-24.png
#   inflating: covid_dataset/COVID/COVID-25.png
#   inflating: covid_dataset/COVID/COVID-26.png
#   inflating: covid_dataset/COVID/COVID-27.png
#   inflating: covid_dataset/COVID/COVID-28.png
#   inflating: covid_dataset/COVID/COVID-29.png
#   inflating: covid_dataset/COVID/COVID-3.png
#   inflating: covid_dataset/COVID/COVID-30.png
#   inflating: covid_dataset/COVID/COVID-31.png
#   inflating: covid_dataset/COVID/COVID-32.png
#   inflating: covid_dataset/COVID/COVID-33.png
#   inflating: covid_dataset/COVID/COVID-34.png
#   inflating: covid_dataset/COVID/COVID-35.png
#   inflating: covid_dataset/COVID/COVID-36.png
#   inflating: covid_dataset/COVID/COVID-37.png
#   inflating: covid_dataset/COVID/COVID-38.png
#   inflating: covid_dataset/COVID/COVID-39.png
#   inflating: covid_dataset/COVID/COVID-4.png
#   inflating: covid_dataset/COVID/COVID-40.png
#   inflating: covid_dataset/COVID/COVID-41.png
#   inflating: covid_dataset/COVID/COVID-42.png
#   inflating: covid_dataset/COVID/COVID-43.png
#   inflating: covid_dataset/COVID/COVID-44.png
#   inflating: covid_dataset/COVID/COVID-45.png
#   inflating: covid_dataset/COVID/COVID-46.png
#   inflating: covid_dataset/COVID/COVID-47.png
#   inflating: covid_dataset/COVID/COVID-48.png
#   inflating: covid_dataset/COVID/COVID-49.png
#   inflating: covid_dataset/COVID/COVID-5.png
#   inflating: covid_dataset/COVID/COVID-50.png
#   inflating: covid_dataset/COVID/COVID-6.png
#   inflating: covid_dataset/COVID/COVID-7.png
#   inflating: covid_dataset/COVID/COVID-8.png
#   inflating: covid_dataset/COVID/COVID-9.png
#    creating: covid_dataset/Normal/
#   inflating: covid_dataset/Normal/Normal-1.png
#   inflating: covid_dataset/Normal/Normal-10.png
#   inflating: covid_dataset/Normal/Normal-11.png
#   inflating: covid_dataset/Normal/Normal-12.png
#   inflating: covid_dataset/Normal/Normal-13.png
#   inflating: covid_dataset/Normal/Normal-14.png
#   inflating: covid_dataset/Normal/Normal-15.png
#   inflating: covid_dataset/Normal/Normal-16.png
#   inflating: covid_dataset/Normal/Normal-17.png
#   inflating: covid_dataset/Normal/Normal-18.png
#   inflating: covid_dataset/Normal/Normal-19.png
#   inflating: covid_dataset/Normal/Normal-2.png
#   inflating: covid_dataset/Normal/Normal-20.png
#   inflating: covid_dataset/Normal/Normal-21.png
#   inflating: covid_dataset/Normal/Normal-22.png
#   inflating: covid_dataset/Normal/Normal-23.png
#   inflating: covid_dataset/Normal/Normal-24.png
#   inflating: covid_dataset/Normal/Normal-25.png
#   inflating: covid_dataset/Normal/Normal-26.png
#   inflating: covid_dataset/Normal/Normal-27.png
#   inflating: covid_dataset/Normal/Normal-28.png
#   inflating: covid_dataset/Normal/Normal-29.png
#   inflating: covid_dataset/Normal/Normal-3.png
#   inflating: covid_dataset/Normal/Normal-30.png
#   inflating: covid_dataset/Normal/Normal-31.png
#   inflating: covid_dataset/Normal/Normal-32.png
#   inflating: covid_dataset/Normal/Normal-33.png
#   inflating: covid_dataset/Normal/Normal-34.png
#   inflating: covid_dataset/Normal/Normal-35.png
#   inflating: covid_dataset/Normal/Normal-36.png
#   inflating: covid_dataset/Normal/Normal-37.png
#   inflating: covid_dataset/Normal/Normal-38.png
#   inflating: covid_dataset/Normal/Normal-39.png
#   inflating: covid_dataset/Normal/Normal-4.png
#   inflating: covid_dataset/Normal/Normal-40.png
#   inflating: covid_dataset/Normal/Normal-41.png
#   inflating: covid_dataset/Normal/Normal-42.png
#   inflating: covid_dataset/Normal/Normal-43.png
#   inflating: covid_dataset/Normal/Normal-44.png
#   inflating: covid_dataset/Normal/Normal-45.png
#   inflating: covid_dataset/Normal/Normal-46.png
#   inflating: covid_dataset/Normal/Normal-47.png
#   inflating: covid_dataset/Normal/Normal-48.png
#   inflating: covid_dataset/Normal/Normal-49.png
#   inflating: covid_dataset/Normal/Normal-5.png
#   inflating: covid_dataset/Normal/Normal-50.png
#   inflating: covid_dataset/Normal/Normal-6.png
#   inflating: covid_dataset/Normal/Normal-7.png
#   inflating: covid_dataset/Normal/Normal-8.png
#   inflating: covid_dataset/Normal/Normal-9.png
#    creating: covid_dataset/Viral Pneumonia/
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-1.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-10.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-11.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-12.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-13.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-14.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-15.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-16.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-17.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-18.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-19.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-2.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-20.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-21.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-22.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-23.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-24.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-25.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-26.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-27.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-28.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-29.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-3.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-30.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-31.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-32.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-33.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-34.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-35.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-36.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-37.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-38.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-39.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-4.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-40.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-41.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-42.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-43.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-44.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-45.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-46.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-47.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-48.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-49.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-5.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-50.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-6.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-7.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-8.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-9.png

# %% [markdown]
# **4. Install split folder python package**
#
# https://pypi.org/project/split-folders/

# %%
# !pip install split_folders
# Out:
# Requirement already satisfied: split_folders in /usr/local/lib/python3.12/dist-packages (0.6.1)

# %% [markdown]
# **5. Splitting the data in training, testing and validation set**

# %%
import splitfolders
splitfolders.ratio("covid_dataset", output="split", seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 150 files [00:00, 5064.12 files/s]

# %% [markdown]
# **6. Loading the dataset with normalization in batches**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Normalize training and validation data in the range of 0 to 1
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Read the training sample and set the batch size
train_generator = train_datagen.flow_from_directory(
        'split/train/',
        target_size=(128, 128),
        batch_size=8,
        seed=100,
        class_mode='categorical')

# Read Validation data from directory and define target size with batch size
validation_generator = validation_datagen.flow_from_directory(
        'split/val/',
        target_size=(128, 128),
        batch_size=8,
        class_mode='categorical',
        seed=1000,
        shuffle=False)

test_generator = test_datagen.flow_from_directory(
        'split/test/',
        target_size=(128, 128),
        batch_size=8,
        seed=500,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 120 images belonging to 3 classes.
# Found 15 images belonging to 3 classes.
# Found 15 images belonging to 3 classes.

# %% [markdown]
# **7. Model Building**

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(128, 128, 3))

# x = layers.Conv2D(32, (3,3), activation='relu')(inputs)
# x = layers.MaxPooling2D(2,2)(x)

# x = layers.Conv2D(64, (3,3), activation='relu')(x)
# x = layers.MaxPooling2D(2,2)(x)

# x = layers.Conv2D(128, (3,3), activation='relu')(x)
# x = layers.MaxPooling2D(2,2)(x)

x = layers.Flatten()(inputs)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.5)(x)

outputs = layers.Dense(3, activation='softmax')(x)

model = keras.Model(inputs, outputs)

# %% [markdown]
# **8. Model Compilation and Training**

# %%
from tensorflow.keras.optimizers import Adam

adam = Adam(learning_rate=0.0001)
# We are going to use accuracy metrics and cross entropy loss as performance parameters
model.compile(adam, loss='categorical_crossentropy', metrics=['accuracy'])  # Use 'accuracy'
# Train the model
history = model.fit(train_generator,
      steps_per_epoch=int(train_generator.samples / train_generator.batch_size),  # Convert to int
      epochs=100,
      validation_data=validation_generator,
      validation_steps=int(validation_generator.samples / validation_generator.batch_size),  # Convert to int
      verbose=1)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.4583 - loss: 1.0873 - val_accuracy: 0.3750 - val_loss: 1.0831
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.3833 - loss: 1.0882 - val_accuracy: 0.6250 - val_loss: 1.0114
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3917 - loss: 1.0786 - val_accuracy: 0.3750 - val_loss: 1.0302
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.5083 - loss: 1.0309 - val_accuracy: 0.8750 - val_loss: 0.9988
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7000 - loss: 0.9585 - val_accuracy: 0.8750 - val_loss: 0.9632
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.6500 - loss: 0.8654 - val_accuracy: 0.8750 - val_loss: 0.8377
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7000 - loss: 0.7898 - val_accuracy: 0.3750 - val_loss: 0.9238
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6667 - loss: 0.7480 - val_accuracy: 0.7500 - val_loss: 0.6757
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7333 - loss: 0.6546 - val_accuracy: 0.8750 - val_loss: 0.6228
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7333 - loss: 0.6555 - val_accuracy: 0.8750 - val_loss: 0.7184
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8250 - loss: 0.5157 - val_accuracy: 0.8750 - val_loss: 0.4783
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7583 - loss: 0.5249 - val_accuracy: 0.8750 - val_loss: 0.4782
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8167 - loss: 0.4570 - val_accuracy: 0.8750 - val_loss: 0.6823
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8417 - loss: 0.4651 - val_accuracy: 0.8750 - val_loss: 0.4380
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8167 - loss: 0.4080 - val_accuracy: 0.8750 - val_loss: 0.4471
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8583 - loss: 0.3755 - val_accuracy: 0.8750 - val_loss: 0.4147
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.8583 - loss: 0.3496 - val_accuracy: 0.8750 - val_loss: 0.4571
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.8917 - loss: 0.3080 - val_accuracy: 0.8750 - val_loss: 0.6299
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8583 - loss: 0.3436 - val_accuracy: 0.8750 - val_loss: 0.3737
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8917 - loss: 0.3214 - val_accuracy: 0.8750 - val_loss: 0.5605
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9333 - loss: 0.2552 - val_accuracy: 0.8750 - val_loss: 0.5512
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9167 - loss: 0.2186 - val_accuracy: 0.7500 - val_loss: 0.3255
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9167 - loss: 0.2107 - val_accuracy: 0.8750 - val_loss: 0.4007
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9333 - loss: 0.1985 - val_accuracy: 0.8750 - val_loss: 0.3860
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9417 - loss: 0.1801 - val_accuracy: 0.8750 - val_loss: 0.3082
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9333 - loss: 0.1737 - val_accuracy: 0.8750 - val_loss: 0.4801
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9250 - loss: 0.1870 - val_accuracy: 0.8750 - val_loss: 0.3676
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9583 - loss: 0.1596 - val_accuracy: 0.8750 - val_loss: 0.4845
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9667 - loss: 0.1392 - val_accuracy: 0.8750 - val_loss: 0.5365
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9667 - loss: 0.1191 - val_accuracy: 0.8750 - val_loss: 0.4198
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9750 - loss: 0.1097 - val_accuracy: 0.8750 - val_loss: 0.4243
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9750 - loss: 0.0905 - val_accuracy: 0.8750 - val_loss: 0.6939
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9333 - loss: 0.1452 - val_accuracy: 0.8750 - val_loss: 0.3466
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9333 - loss: 0.1245 - val_accuracy: 0.8750 - val_loss: 0.4387
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9583 - loss: 0.1305 - val_accuracy: 0.8750 - val_loss: 0.3730
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9833 - loss: 0.0774 - val_accuracy: 0.8750 - val_loss: 0.4455
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9750 - loss: 0.0652 - val_accuracy: 0.8750 - val_loss: 0.2979
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9833 - loss: 0.0596 - val_accuracy: 0.8750 - val_loss: 0.3818
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9667 - loss: 0.1087 - val_accuracy: 0.8750 - val_loss: 0.8856
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9500 - loss: 0.1404 - val_accuracy: 0.8750 - val_loss: 0.5164
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9667 - loss: 0.1059 - val_accuracy: 0.8750 - val_loss: 0.6524
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9667 - loss: 0.0982 - val_accuracy: 0.6250 - val_loss: 0.3773
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9833 - loss: 0.0810 - val_accuracy: 0.8750 - val_loss: 0.5577
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9833 - loss: 0.0524 - val_accuracy: 0.8750 - val_loss: 0.3355
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.9833 - loss: 0.0830 - val_accuracy: 0.8750 - val_loss: 0.6150
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9833 - loss: 0.0596 - val_accuracy: 0.8750 - val_loss: 0.4951
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9833 - loss: 0.0459 - val_accuracy: 0.8750 - val_loss: 0.5554
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9833 - loss: 0.0564 - val_accuracy: 0.8750 - val_loss: 0.4522
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0416 - val_accuracy: 0.8750 - val_loss: 0.4429
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0395 - val_accuracy: 0.8750 - val_loss: 0.3781
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0345 - val_accuracy: 0.8750 - val_loss: 0.5592
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9833 - loss: 0.0452 - val_accuracy: 0.8750 - val_loss: 0.5624
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9917 - loss: 0.0560 - val_accuracy: 0.7500 - val_loss: 0.2644
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9917 - loss: 0.0356 - val_accuracy: 0.8750 - val_loss: 0.3611
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0277 - val_accuracy: 0.8750 - val_loss: 0.3902
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0346 - val_accuracy: 0.8750 - val_loss: 0.3645
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0205 - val_accuracy: 0.8750 - val_loss: 0.5684
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9917 - loss: 0.0270 - val_accuracy: 0.8750 - val_loss: 0.2472
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9917 - loss: 0.0477 - val_accuracy: 0.8750 - val_loss: 0.2677
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0183 - val_accuracy: 0.8750 - val_loss: 0.2229
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8750 - val_loss: 0.4243
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.8750 - val_loss: 0.2806
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8750 - val_loss: 0.4416
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.8750 - val_loss: 0.4532
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.8750 - val_loss: 0.1729
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9917 - loss: 0.0252 - val_accuracy: 0.8750 - val_loss: 0.2279
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 0.0310 - val_accuracy: 0.8750 - val_loss: 0.4811
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 1.0000 - loss: 0.0248 - val_accuracy: 0.8750 - val_loss: 0.5619
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 1.0000 - loss: 0.0296 - val_accuracy: 0.8750 - val_loss: 0.5438
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9917 - loss: 0.0209 - val_accuracy: 0.8750 - val_loss: 0.3979
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9917 - loss: 0.0318 - val_accuracy: 0.8750 - val_loss: 0.2482
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9833 - loss: 0.0372 - val_accuracy: 0.8750 - val_loss: 0.5434
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9917 - loss: 0.0263 - val_accuracy: 0.8750 - val_loss: 0.2541
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9917 - loss: 0.0338 - val_accuracy: 0.8750 - val_loss: 0.2853
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.8750 - val_loss: 0.3686
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.8750 - val_loss: 0.2703
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.8750 - val_loss: 0.3091
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9917 - loss: 0.0218 - val_accuracy: 0.8750 - val_loss: 0.3715
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.8750 - val_loss: 0.3169
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.8750 - val_loss: 0.3997
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.8750 - val_loss: 0.4985
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8750 - val_loss: 0.3267
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.8750 - val_loss: 0.1515
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9833 - loss: 0.0451 - val_accuracy: 0.8750 - val_loss: 0.5770
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 0.8750 - val_loss: 0.2331
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0118 - val_accuracy: 0.8750 - val_loss: 0.1905
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9917 - loss: 0.0396 - val_accuracy: 0.8750 - val_loss: 0.6324
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.8750 - val_loss: 0.5600
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9833 - loss: 0.0253 - val_accuracy: 0.8750 - val_loss: 0.4160
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 1.0000 - loss: 0.0177 - val_accuracy: 0.8750 - val_loss: 0.6438
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.8750 - val_loss: 0.6013
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0142 - val_accuracy: 0.8750 - val_loss: 0.5608
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.8750 - val_loss: 0.5115
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8750 - val_loss: 0.4851
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 1.0000 - loss: 0.0165 - val_accuracy: 0.8750 - val_loss: 0.3792
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8750 - val_loss: 0.6777
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 0.8750 - val_loss: 0.2703
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8750 - val_loss: 0.2918
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.8750 - val_loss: 0.4438
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.8750 - val_loss: 0.6063

# %% [markdown]
# **9. Model saving**

# %%
model.save('covid_classification.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# **10. Model loading**

# %%
from tensorflow.keras import models
model = models.load_model('covid_classification.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# **11. Model weights saving**

# %%
model.save_weights('covid_classification_weights.weights.h5')

# %% [markdown]
# **12. Model weights loading**

# %%
model.load_weights('covid_classification_weights.weights.h5')

# %% [markdown]
# **13. Plotting accuracy and loss graph for training and validation dataset**

# %%
train_acc = history.history['accuracy'] # Change 'acc' to 'accuracy'
val_acc = history.history['val_accuracy'] # Change 'val_acc' to 'val_accuracy'
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
epochs = range(len(train_acc))
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# **14. Evaluate model performance on test dataset**

# %%
test_output = model.evaluate(
    test_generator,
    steps=int(test_generator.samples / test_generator.batch_size),  # Convert steps to an integer
    verbose=1
)
print(test_output)
print(model.metrics_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step - accuracy: 1.0000 - loss: 0.0551
# [0.055067501962184906, 1.0]
# ['loss', 'compile_metrics']

# %% [markdown]
# References:
#
# 1. https://pypi.org/project/split-folders/
# 2. https://keras.io/
